# %%
import csv
import pandas as pd
import numpy as np
import os
import json

# %%
file_path="Community_Health_Indicator_Reports__CHIRS___Latest_Data.csv"

health_stats=pd.read_csv(file_path)

# %%
health_stats.head()
# Out:
#        County Name  Health Topic Number       Health Topic Indicator Number  \
# 0    Mohawk Valley                    1  Cancer Indicators               g1
# 1    North Country                    1  Cancer Indicators               g1
# 2  Tug Hill Seaway                    1  Cancer Indicators               g1
# 3       Central NY                    1  Cancer Indicators               g1
# 4    Southern Tier                    1  Cancer Indicators               g1
#
#                                Indicator  Event Count  \
# 0  All cancer incidence rate per 100,000       5124.0
# 1  All cancer incidence rate per 100,000       5993.0
# 2  All cancer incidence rate per 100,000       4034.0
# 3  All cancer incidence rate per 100,000      18896.0
# 4  All cancer incidence rate per 100,000       8183.0
#
#    Average Number of Denominator Measure Unit  Percent/Rate  \
# 0                       264241.0         Rate         646.4
# 1                       306231.0         Rate         652.3
# 2                       257610.0         Rate         522.0
# 3                      1025519.0         Rate         614.2
# 4                       449813.0         Rate         606.4
#
#    Lower Limit of 95% CI  Upper Limit of 95% CI Data Comments Quartile  \
# 0                    NaN                    NaN           NaN      NaN
# 1                    NaN                    NaN           NaN      NaN
# 2                    NaN                    NaN           NaN      NaN
# 3                    NaN                    NaN           NaN      NaN
# 4                    NaN                    NaN           NaN      NaN
#
#   Data Years                             Data Source  Mapping Distribution  \
# 0  2010-2012  Cancer Registry Data as of April, 2015                   NaN
# 1  2010-2012  Cancer Registry Data as of April, 2015                   NaN
# 2  2010-2012  Cancer Registry Data as of April, 2015                   NaN
# 3  2010-2012  Cancer Registry Data as of April, 2015                   NaN
# 4  2010-2012  Cancer Registry Data as of April, 2015                   NaN
#
#   Location
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
obs_stats=health_stats[health_stats['Indicator']=='Age-adjusted percentage of adults obese (BMI 30 or higher)']

# %%
obs_stats.head()
# Out:
#       County Name  Health Topic Number                    Health Topic  \
# 4821       Albany                   10  Obesity and Related Indicators
# 4822     Allegany                   10  Obesity and Related Indicators
# 4823       Broome                   10  Obesity and Related Indicators
# 4824  Cattaraugus                   10  Obesity and Related Indicators
# 4825       Cayuga                   10  Obesity and Related Indicators
#
#      Indicator Number                                          Indicator  \
# 4821              g75  Age-adjusted percentage of adults obese (BMI 3...
# 4822              g75  Age-adjusted percentage of adults obese (BMI 3...
# 4823              g75  Age-adjusted percentage of adults obese (BMI 3...
# 4824              g75  Age-adjusted percentage of adults obese (BMI 3...
# 4825              g75  Age-adjusted percentage of adults obese (BMI 3...
#
#       Event Count  Average Number of Denominator Measure Unit  Percent/Rate  \
# 4821          NaN                            NaN   Percentage          26.0
# 4822          NaN                            NaN   Percentage          30.6
# 4823          NaN                            NaN   Percentage          31.7
# 4824          NaN                            NaN   Percentage          33.5
# 4825          NaN                            NaN   Percentage          33.0
#
#       Lower Limit of 95% CI  Upper Limit of 95% CI Data Comments  \
# 4821                   21.8                   30.1           NaN
# 4822                   23.9                   37.4           NaN
# 4823                   26.0                   37.3           NaN
# 4824                   27.1                   40.0           NaN
# 4825                   24.8                   41.1           NaN
#
#                      Quartile Data Years  \
# 4821  0 - <   30.3  : Q1 & Q2  2013-2014
# 4822    30.3 - <   32.7  : Q3  2013-2014
# 4823    30.3 - <   32.7  : Q3  2013-2014
# 4824            32.7 +   : Q4  2013-2014
# 4825            32.7 +   : Q4  2013-2014
#
#                                             Data Source  Mapping Distribution  \
# 4821  NYS Expanded Behavioral Risk Factor Surveillan...                   1.0
# 4822  NYS Expanded Behavioral Risk Factor Surveillan...                   2.0
# 4823  NYS Expanded Behavioral Risk Factor Surveillan...                   2.0
# 4824  NYS Expanded Behavioral Risk Factor Surveillan...                   3.0
# 4825  NYS Expanded Behavioral Risk Factor Surveillan...                   3.0
#
#                      Location
# 4821  (42.678066, -73.814233)
# 4822  (42.226801, -78.020567)
# 4823  (42.122015, -75.933191)
# 4824  (42.224267, -78.606673)
# 4825  (42.940095, -76.560755)

# %%
obs_stats=obs_stats[['County Name','Indicator','Percent/Rate','Location']]
obs_stats=obs_stats.rename(columns={"County Name": "County", "Indicator": "Health_Topic","Percent/Rate":"Percentage"})
obs_stats.head()
# Out:
#            County                                       Health_Topic  \
# 4821       Albany  Age-adjusted percentage of adults obese (BMI 3...
# 4822     Allegany  Age-adjusted percentage of adults obese (BMI 3...
# 4823       Broome  Age-adjusted percentage of adults obese (BMI 3...
# 4824  Cattaraugus  Age-adjusted percentage of adults obese (BMI 3...
# 4825       Cayuga  Age-adjusted percentage of adults obese (BMI 3...
#
#       Percentage                 Location
# 4821        26.0  (42.678066, -73.814233)
# 4822        30.6  (42.226801, -78.020567)
# 4823        31.7  (42.122015, -75.933191)
# 4824        33.5  (42.224267, -78.606673)
# 4825        33.0  (42.940095, -76.560755)

# %%
obs_stats
# Out:
#               County                                       Health_Topic  \
# 4821          Albany  Age-adjusted percentage of adults obese (BMI 3...
# 4822        Allegany  Age-adjusted percentage of adults obese (BMI 3...
# 4823          Broome  Age-adjusted percentage of adults obese (BMI 3...
# 4824     Cattaraugus  Age-adjusted percentage of adults obese (BMI 3...
# 4825          Cayuga  Age-adjusted percentage of adults obese (BMI 3...
# ...              ...                                                ...
# 4893      Central NY  Age-adjusted percentage of adults obese (BMI 3...
# 4894   Southern Tier  Age-adjusted percentage of adults obese (BMI 3...
# 4895    Finger Lakes  Age-adjusted percentage of adults obese (BMI 3...
# 4896      Western NY  Age-adjusted percentage of adults obese (BMI 3...
# 4897  New York State  Age-adjusted percentage of adults obese (BMI 3...
#
#       Percentage                 Location
# 4821        26.0  (42.678066, -73.814233)
# 4822        30.6  (42.226801, -78.020567)
# 4823        31.7  (42.122015, -75.933191)
# 4824        33.5  (42.224267, -78.606673)
# 4825        33.0  (42.940095, -76.560755)
# ...          ...                      ...
# 4893        31.5                      NaN
# 4894        29.8                      NaN
# 4895        27.2                      NaN
# 4896        31.1                      NaN
# 4897        24.6                      NaN
#
# [74 rows x 4 columns]

# %%
obs_stats=obs_stats[obs_stats['Location'].notna()]
obs_stats.reset_index(drop=True)
# Out:
#          County                                       Health_Topic  \
# 0        Albany  Age-adjusted percentage of adults obese (BMI 3...
# 1      Allegany  Age-adjusted percentage of adults obese (BMI 3...
# 2        Broome  Age-adjusted percentage of adults obese (BMI 3...
# 3   Cattaraugus  Age-adjusted percentage of adults obese (BMI 3...
# 4        Cayuga  Age-adjusted percentage of adults obese (BMI 3...
# ..          ...                                                ...
# 57        Bronx  Age-adjusted percentage of adults obese (BMI 3...
# 58        Kings  Age-adjusted percentage of adults obese (BMI 3...
# 59     New York  Age-adjusted percentage of adults obese (BMI 3...
# 60       Queens  Age-adjusted percentage of adults obese (BMI 3...
# 61     Richmond  Age-adjusted percentage of adults obese (BMI 3...
#
#     Percentage                 Location
# 0         26.0  (42.678066, -73.814233)
# 1         30.6  (42.226801, -78.020567)
# 2         31.7  (42.122015, -75.933191)
# 3         33.5  (42.224267, -78.606673)
# 4         33.0  (42.940095, -76.560755)
# ..         ...                      ...
# 57        31.0   (40.85589, -73.868294)
# 58        24.8   (40.65642, -73.950691)
# 59        16.8  (40.726966, -74.005966)
# 60        22.1  (40.749338, -73.789673)
# 61        23.2  (40.566763, -74.148102)
#
# [62 rows x 4 columns]

# %%
obs_stats.to_csv("NY_Stats.csv",index=False)

# %%
with open("NY_Stats.csv",'r') as f:
    reader=csv.DictReader(f)
    a=list(reader)
    
print(json.dumps(a,indent=2))
# Out:
# [
#   {
#     "County": "Albany",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "26.0",
#     "Location": "(42.678066, -73.814233)"
#   },
#   {
#     "County": "Allegany",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "30.6",
#     "Location": "(42.226801, -78.020567)"
#   },
#   {
#     "County": "Broome",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "31.7",
#     "Location": "(42.122015, -75.933191)"
#   },
#   {
#     "County": "Cattaraugus",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "33.5",
#     "Location": "(42.224267, -78.606673)"
#   },
#   {
#     "County": "Cayuga",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "33.0",
#     "Location": "(42.940095, -76.560755)"
#   },
#   {
#     "County": "Chautauqua",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "32.1",
#     "Location": "(42.246904, -79.315313)"
#   },
#   {
#     "County": "Chemung",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "29.8",
#     "Location": "(42.116644, -76.812331)"
#   },
#   {
#     "County": "Chenango",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "38.9",
#     "Location": "(42.481798, -75.570013)"
#   },
#   {
#     "County": "Clinton",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "26.8",
#     "Location": "(44.731944, -73.548883)"
#   },
#   {
#     "County": "Columbia",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "24.0",
#     "Location": "(42.276913, -73.682168)"
#   },
#   {
#     "County": "Cortland",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "30.8",
#     "Location": "(42.597101, -76.143291)"
#   },
#   {
#     "County": "Delaware",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "25.8",
#     "Location": "(42.242972, -74.997944)"
#   },
#   {
#     "County": "Dutchess",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "25.5",
#     "Location": "(41.686216, -73.840468)"
#   },
#   {
#     "County": "Erie",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "30.7",
#     "Location": "(42.888143, -78.795544)"
#   },
#   {
#     "County": "Essex",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "37.0",
#     "Location": "(44.166026, -73.685145)"
#   },
#   {
#     "County": "Franklin",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "33.4",
#     "Location": "(44.705699, -74.340621)"
#   },
#   {
#     "County": "Fulton",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "31.4",
#     "Location": "(43.06014, -74.331296)"
#   },
#   {
#     "County": "Genesee",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "30.8",
#     "Location": "(43.000121, -78.172679)"
#   },
#   {
#     "County": "Greene",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "31.4",
#     "Location": "(42.298326, -73.973376)"
#   },
#   {
#     "County": "Hamilton",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "25.9",
#     "Location": "(43.618468, -74.395268)"
#   },
#   {
#     "County": "Herkimer",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "38.2",
#     "Location": "(43.070026, -74.994246)"
#   },
#   {
#     "County": "Jefferson",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "31.8",
#     "Location": "(44.019295, -75.898971)"
#   },
#   {
#     "County": "Lewis",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "33.6",
#     "Location": "(43.785537, -75.446296)"
#   },
#   {
#     "County": "Livingston",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "32.7",
#     "Location": "(42.763754, -77.765392)"
#   },
#   {
#     "County": "Madison",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "32.9",
#     "Location": "(42.986917, -75.720031)"
#   },
#   {
#     "County": "Monroe",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "24.5",
#     "Location": "(43.161748, -77.620143)"
#   },
#   {
#     "County": "Montgomery",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "30.1",
#     "Location": "(42.933637, -74.341972)"
#   },
#   {
#     "County": "Nassau",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "20.8",
#     "Location": "(40.715749, -73.601185)"
#   },
#   {
#     "County": "Niagara",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "30.7",
#     "Location": "(43.134634, -78.856419)"
#   },
#   {
#     "County": "Oneida",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "36.6",
#     "Location": "(43.149482, -75.361773)"
#   },
#   {
#     "County": "Onondaga",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "27.9",
#     "Location": "(43.065629, -76.168033)"
#   },
#   {
#     "County": "Ontario",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "26.8",
#     "Location": "(42.894571, -77.252045)"
#   },
#   {
#     "County": "Orange",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "32.5",
#     "Location": "(41.422459, -74.241929)"
#   },
#   {
#     "County": "Orleans",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "38.5",
#     "Location": "(43.248394, -78.218438)"
#   },
#   {
#     "County": "Oswego",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "33.8",
#     "Location": "(43.39123, -76.31133)"
#   },
#   {
#     "County": "Otsego",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "25.9",
#     "Location": "(42.564852, -75.060334)"
#   },
#   {
#     "County": "Putnam",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "20.5",
#     "Location": "(41.41131, -73.717443)"
#   },
#   {
#     "County": "Rensselaer",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "26.8",
#     "Location": "(42.70098, -73.628669)"
#   },
#   {
#     "County": "Rockland",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "23.1",
#     "Location": "(41.127287, -74.017033)"
#   },
#   {
#     "County": "St. Lawrence",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "32.7",
#     "Location": "(44.689468, -75.242045)"
#   },
#   {
#     "County": "Saratoga",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "25.9",
#     "Location": "(43.00894, -73.786779)"
#   },
#   {
#     "County": "Schenectady",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "32.8",
#     "Location": "(42.809233, -73.946838)"
#   },
#   {
#     "County": "Schoharie",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "28.7",
#     "Location": "(42.643426, -74.434606)"
#   },
#   {
#     "County": "Schuyler",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "22.9",
#     "Location": "(42.38593, -76.872032)"
#   },
#   {
#     "County": "Seneca",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "28.9",
#     "Location": "(42.833627, -76.82753)"
#   },
#   {
#     "County": "Steuben",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "32.8",
#     "Location": "(42.270053, -77.324618)"
#   },
#   {
#     "County": "Suffolk",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "28.4",
#     "Location": "(40.820237, -73.119032)"
#   },
#   {
#     "County": "Sullivan",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "27.7",
#     "Location": "(41.705166, -74.711705)"
#   },
#   {
#     "County": "Tioga",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "36.5",
#     "Location": "(42.120252, -76.29595)"
#   },
#   {
#     "County": "Tompkins",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "21.1",
#     "Location": "(42.461024, -76.478784)"
#   },
#   {
#     "County": "Ulster",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "26.4",
#     "Location": "(41.848374, -74.099412)"
#   },
#   {
#     "County": "Warren",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "30.5",
#     "Location": "(43.403024, -73.716044)"
#   },
#   {
#     "County": "Washington",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "28.4",
#     "Location": "(43.289513, -73.454761)"
#   },
#   {
#     "County": "Wayne",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "36.8",
#     "Location": "(43.144336, -77.117995)"
#   },
#   {
#     "County": "Westchester",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "21.0",
#     "Location": "(41.039278, -73.805386)"
#   },
#   {
#     "County": "Wyoming",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "29.3",
#     "Location": "(42.723641, -78.204473)"
#   },
#   {
#     "County": "Yates",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "31.9",
#     "Location": "(42.634338, -77.078311)"
#   },
#   {
#     "County": "Bronx",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "31.0",
#     "Location": "(40.85589, -73.868294)"
#   },
#   {
#     "County": "Kings",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "24.8",
#     "Location": "(40.65642, -73.950691)"
#   },
#   {
#     "County": "New York",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "16.8",
#     "Location": "(40.726966, -74.005966)"
#   },
#   {
#     "County": "Queens",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "22.1",
#     "Location": "(40.749338, -73.789673)"
#   },
#   {
#     "County": "Richmond",
#     "Health_Topic": "Age-adjusted percentage of adults obese (BMI 30 or higher)",
#     "Percentage": "23.2",
#     "Location": "(40.566763, -74.148102)"
#   }
# ]

# %%
with open('NY_Stats.json','w') as outfile:
    json.dump(a,outfile)

# %%
geo_coord=obs_stats[['County','Location']]
geo_coord.to_csv("Geo_Loc_Counties.csv",index=False)

# %%
with open("Geo_Loc_Counties.csv",'r') as f:
    reader=csv.DictReader(f)
    b=list(reader)
print(json.dumps(b,indent=2))
# Out:
# [
#   {
#     "County": "Albany",
#     "Location": "(42.678066, -73.814233)"
#   },
#   {
#     "County": "Allegany",
#     "Location": "(42.226801, -78.020567)"
#   },
#   {
#     "County": "Broome",
#     "Location": "(42.122015, -75.933191)"
#   },
#   {
#     "County": "Cattaraugus",
#     "Location": "(42.224267, -78.606673)"
#   },
#   {
#     "County": "Cayuga",
#     "Location": "(42.940095, -76.560755)"
#   },
#   {
#     "County": "Chautauqua",
#     "Location": "(42.246904, -79.315313)"
#   },
#   {
#     "County": "Chemung",
#     "Location": "(42.116644, -76.812331)"
#   },
#   {
#     "County": "Chenango",
#     "Location": "(42.481798, -75.570013)"
#   },
#   {
#     "County": "Clinton",
#     "Location": "(44.731944, -73.548883)"
#   },
#   {
#     "County": "Columbia",
#     "Location": "(42.276913, -73.682168)"
#   },
#   {
#     "County": "Cortland",
#     "Location": "(42.597101, -76.143291)"
#   },
#   {
#     "County": "Delaware",
#     "Location": "(42.242972, -74.997944)"
#   },
#   {
#     "County": "Dutchess",
#     "Location": "(41.686216, -73.840468)"
#   },
#   {
#     "County": "Erie",
#     "Location": "(42.888143, -78.795544)"
#   },
#   {
#     "County": "Essex",
#     "Location": "(44.166026, -73.685145)"
#   },
#   {
#     "County": "Franklin",
#     "Location": "(44.705699, -74.340621)"
#   },
#   {
#     "County": "Fulton",
#     "Location": "(43.06014, -74.331296)"
#   },
#   {
#     "County": "Genesee",
#     "Location": "(43.000121, -78.172679)"
#   },
#   {
#     "County": "Greene",
#     "Location": "(42.298326, -73.973376)"
#   },
#   {
#     "County": "Hamilton",
#     "Location": "(43.618468, -74.395268)"
#   },
#   {
#     "County": "Herkimer",
#     "Location": "(43.070026, -74.994246)"
#   },
#   {
#     "County": "Jefferson",
#     "Location": "(44.019295, -75.898971)"
#   },
#   {
#     "County": "Lewis",
#     "Location": "(43.785537, -75.446296)"
#   },
#   {
#     "County": "Livingston",
#     "Location": "(42.763754, -77.765392)"
#   },
#   {
#     "County": "Madison",
#     "Location": "(42.986917, -75.720031)"
#   },
#   {
#     "County": "Monroe",
#     "Location": "(43.161748, -77.620143)"
#   },
#   {
#     "County": "Montgomery",
#     "Location": "(42.933637, -74.341972)"
#   },
#   {
#     "County": "Nassau",
#     "Location": "(40.715749, -73.601185)"
#   },
#   {
#     "County": "Niagara",
#     "Location": "(43.134634, -78.856419)"
#   },
#   {
#     "County": "Oneida",
#     "Location": "(43.149482, -75.361773)"
#   },
#   {
#     "County": "Onondaga",
#     "Location": "(43.065629, -76.168033)"
#   },
#   {
#     "County": "Ontario",
#     "Location": "(42.894571, -77.252045)"
#   },
#   {
#     "County": "Orange",
#     "Location": "(41.422459, -74.241929)"
#   },
#   {
#     "County": "Orleans",
#     "Location": "(43.248394, -78.218438)"
#   },
#   {
#     "County": "Oswego",
#     "Location": "(43.39123, -76.31133)"
#   },
#   {
#     "County": "Otsego",
#     "Location": "(42.564852, -75.060334)"
#   },
#   {
#     "County": "Putnam",
#     "Location": "(41.41131, -73.717443)"
#   },
#   {
#     "County": "Rensselaer",
#     "Location": "(42.70098, -73.628669)"
#   },
#   {
#     "County": "Rockland",
#     "Location": "(41.127287, -74.017033)"
#   },
#   {
#     "County": "St. Lawrence",
#     "Location": "(44.689468, -75.242045)"
#   },
#   {
#     "County": "Saratoga",
#     "Location": "(43.00894, -73.786779)"
#   },
#   {
#     "County": "Schenectady",
#     "Location": "(42.809233, -73.946838)"
#   },
#   {
#     "County": "Schoharie",
#     "Location": "(42.643426, -74.434606)"
#   },
#   {
#     "County": "Schuyler",
#     "Location": "(42.38593, -76.872032)"
#   },
#   {
#     "County": "Seneca",
#     "Location": "(42.833627, -76.82753)"
#   },
#   {
#     "County": "Steuben",
#     "Location": "(42.270053, -77.324618)"
#   },
#   {
#     "County": "Suffolk",
#     "Location": "(40.820237, -73.119032)"
#   },
#   {
#     "County": "Sullivan",
#     "Location": "(41.705166, -74.711705)"
#   },
#   {
#     "County": "Tioga",
#     "Location": "(42.120252, -76.29595)"
#   },
#   {
#     "County": "Tompkins",
#     "Location": "(42.461024, -76.478784)"
#   },
#   {
#     "County": "Ulster",
#     "Location": "(41.848374, -74.099412)"
#   },
#   {
#     "County": "Warren",
#     "Location": "(43.403024, -73.716044)"
#   },
#   {
#     "County": "Washington",
#     "Location": "(43.289513, -73.454761)"
#   },
#   {
#     "County": "Wayne",
#     "Location": "(43.144336, -77.117995)"
#   },
#   {
#     "County": "Westchester",
#     "Location": "(41.039278, -73.805386)"
#   },
#   {
#     "County": "Wyoming",
#     "Location": "(42.723641, -78.204473)"
#   },
#   {
#     "County": "Yates",
#     "Location": "(42.634338, -77.078311)"
#   },
#   {
#     "County": "Bronx",
#     "Location": "(40.85589, -73.868294)"
#   },
#   {
#     "County": "Kings",
#     "Location": "(40.65642, -73.950691)"
#   },
#   {
#     "County": "New York",
#     "Location": "(40.726966, -74.005966)"
#   },
#   {
#     "County": "Queens",
#     "Location": "(40.749338, -73.789673)"
#   },
#   {
#     "County": "Richmond",
#     "Location": "(40.566763, -74.148102)"
#   }
# ]

# %%
with open('Geo_Loc_Counties.json','w') as outfile:
    json.dump(b,outfile)
