# %%
import csv
import pandas as pd
import numpy as np
import os
import json

# %%
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 1   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 2   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 3   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 4   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# ..                ...                                                ...
# 57  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 58  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 59  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 60  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
# 61  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Poly...
#
# [62 rows x 2 columns]
